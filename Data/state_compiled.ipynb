# 28  0.4386  0.4530  0.4406  0.4348  0.4466
# 29  0.4794  0.4836  0.4782  0.4853  0.4815
# 30  0.4776  0.4891  0.4768  0.4861  0.4796
# 31  0.5157  0.5130  0.5149  0.5140  0.5208
# 32  0.4763  0.4782  0.4743  0.4801  0.4768
# 33  0.4546  0.4427  0.4558  0.4531  0.4678
# 34  0.4642  0.4667  0.4651  0.4687  0.4691
# 35  0.4658  0.4687  0.4739  0.4618  0.4743
# 36  0.4593  0.4582  0.4500  0.4611  0.4679
# 37  0.4777  0.4747  0.4745  0.4720  0.4778
# 38  0.4722  0.4700  0.4628  0.4680  0.4640
# 39  0.4795  0.4762  0.4747  0.4760  0.4757
# 40  0.4488  0.4445  0.4360  0.4522  0.4487
# 41  0.4822  0.4778  0.4749  0.4821  0.4694
# 42  0.4781  0.4822  0.4753  0.4784  0.4796
# 43  0.4225  0.4269  0.4268  0.4449  0.4264
# 44  0.4525  0.4473  0.4471  0.4527  0.4452
# 45  0.4674  0.4754  0.4690  0.4724  0.4755
# 46  0.4561  0.4574  0.4577  0.4704  0.4742
# 47  0.4686  0.4742  0.4644  0.4858  0.4804
# 48  0.4467  0.4483  0.4391  0.4464  0.4510
# 49  0.4326  0.4555  0.4345  0.4638  0.4437

# %%
gini = pd.melt(gini, id_vars = "State", var_name = "Year", value_name = "gini")

# %%
gini
# Out:
#              State  Year    gini
# 0          Alabama  2010  0.4720
# 1           Alaska  2010  0.4220
# 2          Arizona  2010  0.4550
# 3         Arkansas  2010  0.4580
# 4       California  2010  0.4710
# ..             ...   ...     ...
# 595       Virginia  2022  0.4755
# 596     Washington  2022  0.4742
# 597  West Virginia  2022  0.4804
# 598      Wisconsin  2022  0.4510
# 599        Wyoming  2022  0.4437
#
# [600 rows x 3 columns]

# %%
minwage = pd.read_csv("min_wage.csv", dtype = {"Year": str})

# %%
minwage
# Out:
#     State or other jurisdiction  Year  min_wage
# 0                Federal (FLSA)  2010      7.25
# 1                       Alabama  2010      7.25
# 2                        Alaska  2010      7.75
# 3                       Arizona  2010      7.25
# 4                      Arkansas  2010      6.25
# ..                          ...   ...       ...
# 710                     Wyoming  2022      5.15
# 711        District of Columbia  2022     16.10
# 712                        Guam  2022      9.25
# 713                 Puerto Rico  2022      7.25
# 714         U.S. Virgin Islands  2022     10.50
#
# [715 rows x 3 columns]

# %%
minwage = minwage.rename(columns = {"State or other jurisdiction": "State"})

# %%
minwage = minwage[minwage["State"].isin(gini["State"])]

# %%
minwage
# Out:
#              State  Year  min_wage
# 1          Alabama  2010      7.25
# 2           Alaska  2010      7.75
# 3          Arizona  2010      7.25
# 4         Arkansas  2010      6.25
# 5       California  2010      8.00
# ..             ...   ...       ...
# 706       Virginia  2022     11.00
# 707     Washington  2022     14.49
# 708  West Virginia  2022      8.75
# 709      Wisconsin  2022      7.25
# 710        Wyoming  2022      5.15
#
# [650 rows x 3 columns]

# %%
minwage = minwage[minwage["Year"] != "2020"]
minwage.dtypes
# Out:
# State        object
# Year         object
# min_wage    float64
# dtype: object

# %%
minwage
print(type(minwage["Year"][1]))
print(type(gini["Year"][1]))
# Out:
# <class 'str'>
# <class 'str'>

# %%
gini = gini.set_index(["State", "Year"])

# %%
minwage = minwage.set_index(["State", "Year"])

# %%
state_econ = pd.concat([gini, minwage], axis = 1)

# %%
state_econ
# Out:
#                       gini  min_wage
# State         Year
# Alabama       2010  0.4720      7.25
# Alaska        2010  0.4220      7.75
# Arizona       2010  0.4550      7.25
# Arkansas      2010  0.4580      6.25
# California    2010  0.4710      8.00
# ...                    ...       ...
# Virginia      2022  0.4755     11.00
# Washington    2022  0.4742     14.49
# West Virginia 2022  0.4804      8.75
# Wisconsin     2022  0.4510      7.25
# Wyoming       2022  0.4437      5.15
#
# [600 rows x 2 columns]

# %%
gini = gini.reset_index()

# %%
unemployment = pd.read_csv("unemployment_data.csv")

# %%
unemployment
# Out:
#              State  Year  unemployment
# 0          Alabama  2010     10.375000
# 1           Alaska  2010      8.133333
# 2          Arizona  2010     10.300000
# 3         Arkansas  2010      7.858333
# 4       California  2010     12.458333
# ..             ...   ...           ...
# 631       Virginia  2022      2.833333
# 632     Washington  2022      4.175000
# 633  West Virginia  2022      3.916667
# 634      Wisconsin  2022      2.933333
# 635        Wyoming  2022      3.566667
#
# [636 rows x 3 columns]

# %%
def merge_data(path, state_econ):
    data = pd.read_csv(path,dtype = {"Year": str} )
    data = data[data["State"].isin(gini["State"])]
    data = data.set_index(["State", "Year"])
    state_econ = pd.concat([state_econ, data], axis = 1)
    return state_econ

# %%
state_econ = merge_data("unemployment_data.csv", state_econ)

# %%
state_econ
# Out:
#                       gini  min_wage  unemployment
# State         Year
# Alabama       2010  0.4720      7.25     10.375000
# Alaska        2010  0.4220      7.75      8.133333
# Arizona       2010  0.4550      7.25     10.300000
# Arkansas      2010  0.4580      6.25      7.858333
# California    2010  0.4710      8.00     12.458333
# ...                    ...       ...           ...
# Virginia      2022  0.4755     11.00      2.833333
# Washington    2022  0.4742     14.49      4.175000
# West Virginia 2022  0.4804      8.75      3.916667
# Wisconsin     2022  0.4510      7.25      2.933333
# Wyoming       2022  0.4437      5.15      3.566667
#
# [600 rows x 3 columns]

# %%
gdp = pd.read_csv("GDP_Data/state_gdp.csv")

# %%
gdp
# Out:
#              State  Year  GDP (in millions USD)
# 0          Alabama  2010               175470.1
# 1           Alaska  2010                52947.7
# 2          Arizona  2010               248125.3
# 3         Arkansas  2010               100970.8
# 4       California  2010              1973511.9
# ..             ...   ...                    ...
# 495       Virginia  2019               556905.2
# 496     Washington  2019               612996.5
# 497  West Virginia  2019                78863.9
# 498      Wisconsin  2019               349416.5
# 499        Wyoming  2019                40420.1
#
# [500 rows x 3 columns]

# %%
state_econ = merge_data("GDP_Data/state_gdp.csv",state_econ)
state_econ
# Out:
#                       gini  min_wage  unemployment  GDP (in millions USD)
# State         Year
# Alabama       2010  0.4720      7.25     10.375000               175470.1
# Alaska        2010  0.4220      7.75      8.133333                52947.7
# Arizona       2010  0.4550      7.25     10.300000               248125.3
# Arkansas      2010  0.4580      6.25      7.858333               100970.8
# California    2010  0.4710      8.00     12.458333              1973511.9
# ...                    ...       ...           ...                    ...
# Virginia      2022  0.4755     11.00      2.833333                    NaN
# Washington    2022  0.4742     14.49      4.175000                    NaN
# West Virginia 2022  0.4804      8.75      3.916667                    NaN
# Wisconsin     2022  0.4510      7.25      2.933333                    NaN
# Wyoming       2022  0.4437      5.15      3.566667                    NaN
#
# [600 rows x 4 columns]

# %%
state_econ = merge_data("Population/state_population.csv", state_econ)

# %%
state_econ
# Out:
#                       gini  min_wage  unemployment  GDP (in millions USD)  \
# State         Year
# Alabama       2010  0.4720      7.25     10.375000               175470.1
# Alaska        2010  0.4220      7.75      8.133333                52947.7
# Arizona       2010  0.4550      7.25     10.300000               248125.3
# Arkansas      2010  0.4580      6.25      7.858333               100970.8
# California    2010  0.4710      8.00     12.458333              1973511.9
# ...                    ...       ...           ...                    ...
# Virginia      2022  0.4755     11.00      2.833333                    NaN
# Washington    2022  0.4742     14.49      4.175000                    NaN
# West Virginia 2022  0.4804      8.75      3.916667                    NaN
# Wisconsin     2022  0.4510      7.25      2.933333                    NaN
# Wyoming       2022  0.4437      5.15      3.566667                    NaN
#
#                     Population
# State         Year
# Alabama       2010     4785298
# Alaska        2010      713985
# Arizona       2010     6413737
# Arkansas      2010     2921606
# California    2010    37349363
# ...                        ...
# Virginia      2022     8683619
# Washington    2022     7785786
# West Virginia 2022     1775156
# Wisconsin     2022     5892539
# Wyoming       2022      581381
#
# [600 rows x 5 columns]

# %%
state_econ = merge_data("College Degree/state_college_degree.csv", state_econ)

# %%
state_econ
# Out:
#                       gini  min_wage  unemployment  GDP (in millions USD)  \
# State         Year
# Alabama       2010  0.4720      7.25     10.375000               175470.1
# Alaska        2010  0.4220      7.75      8.133333                52947.7
# Arizona       2010  0.4550      7.25     10.300000               248125.3
# Arkansas      2010  0.4580      6.25      7.858333               100970.8
# California    2010  0.4710      8.00     12.458333              1973511.9
# ...                    ...       ...           ...                    ...
# Virginia      2022  0.4755     11.00      2.833333                    NaN
# Washington    2022  0.4742     14.49      4.175000                    NaN
# West Virginia 2022  0.4804      8.75      3.916667                    NaN
# Wisconsin     2022  0.4510      7.25      2.933333                    NaN
# Wyoming       2022  0.4437      5.15      3.566667                    NaN
#
#                     Population  Residents with Bachelor's Degree or Higher
# State         Year
# Alabama       2010     4785298                                      439863
# Alaska        2010      713985                                       83346
# Arizona       2010     6413737                                      691889
# Arkansas      2010     2921606                                      252888
# California    2010    37349363                                     4610875
# ...                        ...                                         ...
# Virginia      2022     8683619                                     1409942
# Washington    2022     7785786                                     1302707
# West Virginia 2022     1775156                                      188793
# Wisconsin     2022     5892539                                      885548
# Wyoming       2022      581381                                       71812
#
# [600 rows x 6 columns]

# %%
state_econ = state_econ.dropna()

# %%
state_econ
# Out:
#                       gini  min_wage  unemployment  GDP (in millions USD)  \
# State         Year
# Alabama       2010  0.4720      7.25     10.375000               175470.1
# Alaska        2010  0.4220      7.75      8.133333                52947.7
# Arizona       2010  0.4550      7.25     10.300000               248125.3
# Arkansas      2010  0.4580      6.25      7.858333               100970.8
# California    2010  0.4710      8.00     12.458333              1973511.9
# ...                    ...       ...           ...                    ...
# Virginia      2019  0.4690      7.25      2.758333               556905.2
# Washington    2019  0.4577     13.50      4.233333               612996.5
# West Virginia 2019  0.4644      8.75      4.933333                78863.9
# Wisconsin     2019  0.4391      7.25      3.166667               349416.5
# Wyoming       2019  0.4345      5.15      3.716667                40420.1
#
#                     Population  Residents with Bachelor's Degree or Higher
# State         Year
# Alabama       2010     4785298                                      439863
# Alaska        2010      713985                                       83346
# Arizona       2010     6413737                                      691889
# Arkansas      2010     2921606                                      252888
# California    2010    37349363                                     4610875
# ...                        ...                                         ...
# Virginia      2019     8535519                                     1312800
# Washington    2019     7614893                                     1204728
# West Virginia 2019     1792147                                      161686
# Wisconsin     2019     5822434                                      829878
# Wyoming       2019      578759                                       73183
#
# [500 rows x 6 columns]

# %%
state_econ["GDP per Capita"] = state_econ["GDP (in millions USD)"]/state_econ["Population"]
# Out:
# /tmp/ipykernel_1072015/1593311554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_econ["GDP per Capita"] = state_econ["GDP (in millions USD)"]/state_econ["Population"]

# %%
state_econ
# Out:
#                       gini  min_wage  unemployment  GDP (in millions USD)  \
# State         Year
# Alabama       2010  0.4720      7.25     10.375000               175470.1
# Alaska        2010  0.4220      7.75      8.133333                52947.7
# Arizona       2010  0.4550      7.25     10.300000               248125.3
# Arkansas      2010  0.4580      6.25      7.858333               100970.8
# California    2010  0.4710      8.00     12.458333              1973511.9
# ...                    ...       ...           ...                    ...
# Virginia      2019  0.4690      7.25      2.758333               556905.2
# Washington    2019  0.4577     13.50      4.233333               612996.5
# West Virginia 2019  0.4644      8.75      4.933333                78863.9
# Wisconsin     2019  0.4391      7.25      3.166667               349416.5
# Wyoming       2019  0.4345      5.15      3.716667                40420.1
#
#                     Population  Residents with Bachelor's Degree or Higher  \
# State         Year
# Alabama       2010     4785298                                      439863
# Alaska        2010      713985                                       83346
# Arizona       2010     6413737                                      691889
# Arkansas      2010     2921606                                      252888
# California    2010    37349363                                     4610875
# ...                        ...                                         ...
# Virginia      2019     8535519                                     1312800
# Washington    2019     7614893                                     1204728
# West Virginia 2019     1792147                                      161686
# Wisconsin     2019     5822434                                      829878
# Wyoming       2019      578759                                       73183
#
#                     GDP per Capita
# State         Year
# Alabama       2010        0.036669
# Alaska        2010        0.074158
# Arizona       2010        0.038687
# Arkansas      2010        0.034560
# California    2010        0.052839
# ...                            ...
# Virginia      2019        0.065246
# Washington    2019        0.080500
# West Virginia 2019        0.044005
# Wisconsin     2019        0.060012
# Wyoming       2019        0.069839
#
# [500 rows x 7 columns]

# %%
state_econ["% with College Degree"] = state_econ["Residents with Bachelor's Degree or Higher"]/state_econ["Population"]
# Out:
# /tmp/ipykernel_1072015/2849559231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_econ["% with College Degree"] = state_econ["Residents with Bachelor's Degree or Higher"]/state_econ["Population"]

# %%
state_econ
# Out:
#                       gini  min_wage  unemployment  GDP (in millions USD)  \
# State         Year
# Alabama       2010  0.4720      7.25     10.375000               175470.1
# Alaska        2010  0.4220      7.75      8.133333                52947.7
# Arizona       2010  0.4550      7.25     10.300000               248125.3
# Arkansas      2010  0.4580      6.25      7.858333               100970.8
# California    2010  0.4710      8.00     12.458333              1973511.9
# ...                    ...       ...           ...                    ...
# Virginia      2019  0.4690      7.25      2.758333               556905.2
# Washington    2019  0.4577     13.50      4.233333               612996.5
# West Virginia 2019  0.4644      8.75      4.933333                78863.9
# Wisconsin     2019  0.4391      7.25      3.166667               349416.5
# Wyoming       2019  0.4345      5.15      3.716667                40420.1
#
#                     Population  Residents with Bachelor's Degree or Higher  \
# State         Year
# Alabama       2010     4785298                                      439863
# Alaska        2010      713985                                       83346
# Arizona       2010     6413737                                      691889
# Arkansas      2010     2921606                                      252888
# California    2010    37349363                                     4610875
# ...                        ...                                         ...
# Virginia      2019     8535519                                     1312800
# Washington    2019     7614893                                     1204728
# West Virginia 2019     1792147                                      161686
# Wisconsin     2019     5822434                                      829878
# Wyoming       2019      578759                                       73183
#
#                     GDP per Capita  % with College Degree
# State         Year
# Alabama       2010        0.036669               0.091920
# Alaska        2010        0.074158               0.116734
# Arizona       2010        0.038687               0.107876
# Arkansas      2010        0.034560               0.086558
# California    2010        0.052839               0.123453
# ...                            ...                    ...
# Virginia      2019        0.065246               0.153804
# Washington    2019        0.080500               0.158207
# West Virginia 2019        0.044005               0.090219
# Wisconsin     2019        0.060012               0.142531
# Wyoming       2019        0.069839               0.126448
#
# [500 rows x 8 columns]

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# %%
#scaler = StandardScaler()
#scaler.set_output(transform = "pandas")
#scaler.fit_transform(state_econ)

# %%
model = sm.OLS(state_econ["gini"],sm.add_constant(state_econ[state_econ.columns[1:]]))

# %%
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   gini   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.283
# Method:                 Least Squares   F-statistic:                     29.19
# Date:                Sat, 25 Nov 2023   Prob (F-statistic):           1.09e-33
# Time:                        21:50:57   Log-Likelihood:                 1344.7
# No. Observations:                 500   AIC:                            -2673.
# Df Residuals:                     492   BIC:                            -2640.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# const                                          0.4767      0.009     52.777      0.000       0.459       0.494
# min_wage                                       0.0014      0.001      2.526      0.012       0.000       0.003
# unemployment                                  -0.0001      0.000     -0.297      0.767      -0.001       0.001
# GDP (in millions USD)                       9.086e-09   1.31e-08      0.696      0.487   -1.66e-08    3.47e-08
# Population                                 -1.623e-09   1.18e-09     -1.378      0.169   -3.94e-09    6.92e-10
# Residents with Bachelor's Degree or Higher  1.917e-08    1.2e-08      1.600      0.110   -4.37e-09    4.27e-08
# GDP per Capita                                -0.1083      0.104     -1.036      0.301      -0.314       0.097
# % with College Degree                         -0.2230      0.068     -3.299      0.001      -0.356      -0.090
# ==============================================================================
# Omnibus:                        0.567   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.753   Jarque-Bera (JB):                0.406
# Skew:                          -0.049   Prob(JB):                        0.816
# Kurtosis:                       3.099   Cond. No.                     1.43e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.43e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
