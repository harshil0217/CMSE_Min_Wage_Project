# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
#Imputer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("../Data/state_econ.csv")
df
# Out:
#              State  Year    gini  min_wage  unemployment  \
# 0          Alabama  2010  0.4720      7.25     10.375000
# 1           Alaska  2010  0.4220      7.75      8.133333
# 2          Arizona  2010  0.4550      7.25     10.300000
# 3         Arkansas  2010  0.4580      6.25      7.858333
# 4       California  2010  0.4710      8.00     12.458333
# ..             ...   ...     ...       ...           ...
# 495       Virginia  2019  0.4690      7.25      2.758333
# 496     Washington  2019  0.4577     13.50      4.233333
# 497  West Virginia  2019  0.4644      8.75      4.933333
# 498      Wisconsin  2019  0.4391      7.25      3.166667
# 499        Wyoming  2019  0.4345      5.15      3.716667
#
#      GDP (in millions USD)  Population  \
# 0                 175470.1   4785298.0
# 1                  52947.7    713985.0
# 2                 248125.3   6413737.0
# 3                 100970.8   2921606.0
# 4                1973511.9  37349363.0
# ..                     ...         ...
# 495               556905.2   8535519.0
# 496               612996.5   7614893.0
# 497                78863.9   1792147.0
# 498               349416.5   5822434.0
# 499                40420.1    578759.0
#
#      Residents with Bachelor's Degree or Higher  GDP per Capita  \
# 0                                      439863.0    36668.583649
# 1                                       83346.0    74158.000518
# 2                                      691889.0    38686.541091
# 3                                      252888.0    34560.033078
# 4                                     4610875.0    52839.238517
# ..                                          ...             ...
# 495                                   1312800.0    65245.616582
# 496                                   1204728.0    80499.686601
# 497                                    161686.0    44005.262961
# 498                                    829878.0    60012.101468
# 499                                     73183.0    69839.259519
#
#      % with College Degree  Union Membership %  Adjusted Household Income  \
# 0                 9.191967                10.1                    43464.0
# 1                11.673354                22.9                    63648.0
# 2                10.787611                 6.4                    47044.0
# 3                 8.655787                 4.0                    39018.0
# 4                12.345257                17.5                    57020.0
# ..                     ...                 ...                        ...
# 495              15.380436                11.2                    92610.0
# 496              15.820682                 4.0                    93910.0
# 497               9.021916                10.2                    61170.0
# 498              14.253111                 8.1                    76720.0
# 499              12.644814                 7.3                    74190.0
#
#      Unadjusted Household Income
# 0                        47624.0
# 1                        69739.0
# 2                        51546.0
# 3                        42752.0
# 4                        62477.0
# ..                           ...
# 495                      92610.0
# 496                      93910.0
# 497                      61170.0
# 498                      76720.0
# 499                      74190.0
#
# [500 rows x 13 columns]

# %%
df = df.set_index(["State", "Year"])
scaleddf = StandardScaler().fit_transform(df)

scaleddf
# Out:
# array([[ 0.53189031, -0.2681927 ,  2.06257411, ...,  0.00306234,
#         -1.32542821, -1.24697584],
#        [-2.02527465,  0.06521444,  1.06216944, ...,  2.54838743,
#          0.34867599,  0.66569167],
#        [-0.33754577, -0.2681927 ,  2.02910332, ..., -0.73269569,
#         -1.02849534, -0.9077725 ],
#        ...,
#        [ 0.14320124,  0.73202871, -0.36591753, ...,  0.0229477 ,
#          0.14314536, -0.07541834],
#        [-1.15072423, -0.2681927 , -1.15434055, ..., -0.3946447 ,
#          1.43289568,  1.26945978],
#        [-1.38598341, -1.66850268, -0.9088881 , ..., -0.55372752,
#          1.22305206,  1.05064681]])

# %%
features = scaleddf[:, :-1]
labels = scaleddf[:, -1]
trainvec, testvec, trainlabel, testlabel = train_test_split(features, labels, test_size=0.2, random_state = 420)
#print(features,labels)

# %%
param_grid = {'C': [1000.0, 10000.0,100000],
              'gamma': [0.0001, 0.001, 0.01,0.1],
              'kernel': ['rbf']}
clf = GridSearchCV(SVR(), param_grid)

results = clf.fit(trainvec, trainlabel)
error = mean_squared_error(testlabel, clf.predict(testvec))
print("Mean squared error =",error)
# Out:
# Mean squared error = 0.007249584461116653

# %%
print("Best estimator found by grid search:")
print(clf.best_estimator_)
print("Best parameters found by grid search:")
print(clf.best_params_)
# Out:
# Best estimator found by grid search:
# SVR(C=1000.0, gamma=0.001)
# Best parameters found by grid search:
# {'C': 1000.0, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
pred_labels = clf.predict(testvec)

#print(y_test)
#print(pred_labels)
print("R^2 =", r2_score(testlabel, clf.predict(testvec)))
# Out:
# R^2 = 0.9919997207789887

# %%
plt.scatter(testlabel, pred_labels)
plt.xlabel("Actual Gini")
plt.ylabel("Predicted Gini")
plt.title("SVR Predictions vs. Actual Values")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 best_clf = clf.best_estimator
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator'
