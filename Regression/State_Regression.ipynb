# %%
import pandas as pd

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# %%
state_econ = pd.read_csv("../Data/state_econ.csv")

# %%
state_econ
# Out:
#              State  Year    gini  min_wage  unemployment  \
# 0          Alabama  2010  0.4720      7.25     10.375000
# 1           Alaska  2010  0.4220      7.75      8.133333
# 2          Arizona  2010  0.4550      7.25     10.300000
# 3         Arkansas  2010  0.4580      6.25      7.858333
# 4       California  2010  0.4710      8.00     12.458333
# ..             ...   ...     ...       ...           ...
# 495       Virginia  2019  0.4690      7.25      2.758333
# 496     Washington  2019  0.4577     13.50      4.233333
# 497  West Virginia  2019  0.4644      8.75      4.933333
# 498      Wisconsin  2019  0.4391      7.25      3.166667
# 499        Wyoming  2019  0.4345      5.15      3.716667
#
#      GDP (in millions USD)  Population  \
# 0                 175470.1     4785298
# 1                  52947.7      713985
# 2                 248125.3     6413737
# 3                 100970.8     2921606
# 4                1973511.9    37349363
# ..                     ...         ...
# 495               556905.2     8535519
# 496               612996.5     7614893
# 497                78863.9     1792147
# 498               349416.5     5822434
# 499                40420.1      578759
#
#      Residents with Bachelor's Degree or Higher  GDP per Capita  \
# 0                                        439863        0.036669
# 1                                         83346        0.074158
# 2                                        691889        0.038687
# 3                                        252888        0.034560
# 4                                       4610875        0.052839
# ..                                          ...             ...
# 495                                     1312800        0.065246
# 496                                     1204728        0.080500
# 497                                      161686        0.044005
# 498                                      829878        0.060012
# 499                                       73183        0.069839
#
#      % with College Degree  Union Membership %
# 0                 0.091920                10.1
# 1                 0.116734                22.9
# 2                 0.107876                 6.4
# 3                 0.086558                 4.0
# 4                 0.123453                17.5
# ..                     ...                 ...
# 495               0.153804                11.2
# 496               0.158207                 4.0
# 497               0.090219                10.2
# 498               0.142531                 8.1
# 499               0.126448                 7.3
#
# [500 rows x 11 columns]

# %%
state_econ = state_econ.set_index(["State", "Year"])

# %%
state_econ
# Out:
#                       gini  min_wage  unemployment  GDP (in millions USD)  \
# State         Year
# Alabama       2010  0.4720      7.25     10.375000               175470.1
# Alaska        2010  0.4220      7.75      8.133333                52947.7
# Arizona       2010  0.4550      7.25     10.300000               248125.3
# Arkansas      2010  0.4580      6.25      7.858333               100970.8
# California    2010  0.4710      8.00     12.458333              1973511.9
# ...                    ...       ...           ...                    ...
# Virginia      2019  0.4690      7.25      2.758333               556905.2
# Washington    2019  0.4577     13.50      4.233333               612996.5
# West Virginia 2019  0.4644      8.75      4.933333                78863.9
# Wisconsin     2019  0.4391      7.25      3.166667               349416.5
# Wyoming       2019  0.4345      5.15      3.716667                40420.1
#
#                     Population  Residents with Bachelor's Degree or Higher  \
# State         Year
# Alabama       2010     4785298                                      439863
# Alaska        2010      713985                                       83346
# Arizona       2010     6413737                                      691889
# Arkansas      2010     2921606                                      252888
# California    2010    37349363                                     4610875
# ...                        ...                                         ...
# Virginia      2019     8535519                                     1312800
# Washington    2019     7614893                                     1204728
# West Virginia 2019     1792147                                      161686
# Wisconsin     2019     5822434                                      829878
# Wyoming       2019      578759                                       73183
#
#                     GDP per Capita  % with College Degree  Union Membership %
# State         Year
# Alabama       2010        0.036669               0.091920                10.1
# Alaska        2010        0.074158               0.116734                22.9
# Arizona       2010        0.038687               0.107876                 6.4
# Arkansas      2010        0.034560               0.086558                 4.0
# California    2010        0.052839               0.123453                17.5
# ...                            ...                    ...                 ...
# Virginia      2019        0.065246               0.153804                11.2
# Washington    2019        0.080500               0.158207                 4.0
# West Virginia 2019        0.044005               0.090219                10.2
# Wisconsin     2019        0.060012               0.142531                 8.1
# Wyoming       2019        0.069839               0.126448                 7.3
#
# [500 rows x 9 columns]

# %%
scaler = StandardScaler()
scaler.set_output(transform = "pandas")
scaler.fit_transform(state_econ)
# Out:
#                         gini  min_wage  unemployment  GDP (in millions USD)  \
# State         Year
# Alabama       2010  0.531890 -0.268193      2.062574              -0.399253
# Alaska        2010 -2.025275  0.065214      1.062169              -0.672484
# Arizona       2010 -0.337546 -0.268193      2.029103              -0.237228
# Arkansas      2010 -0.184116 -0.935007      0.939443              -0.565390
# California    2010  0.480747  0.231918      2.992318               3.610467
# ...                      ...       ...           ...                    ...
# Virginia      2019  0.378460 -0.268193     -1.336570               0.451366
# Washington    2019 -0.199459  3.899397     -0.678312               0.576452
# West Virginia 2019  0.143201  0.732029     -0.365918              -0.614689
# Wisconsin     2019 -1.150724 -0.268193     -1.154341              -0.011344
# Wyoming       2019 -1.385983 -1.668503     -0.908888              -0.700421
#
#                     Population  Residents with Bachelor's Degree or Higher  \
# State         Year
# Alabama       2010   -0.224515                                   -0.397237
# Alaska        2010   -0.798499                                   -0.777665
# Arizona       2010    0.005067                                   -0.128308
# Arkansas      2010   -0.487263                                   -0.596752
# California    2010    4.366450                                    4.053519
# ...                        ...                                         ...
# Virginia      2019    0.304201                                    0.534247
# Washington    2019    0.174409                                    0.418926
# West Virginia 2019   -0.646497                                   -0.694071
# Wisconsin     2019   -0.078296                                    0.018936
# Wyoming       2019   -0.817563                                   -0.788510
#
#                     GDP per Capita  % with College Degree  Union Membership %
# State         Year
# Alabama       2010       -1.508554              -1.608426            0.003062
# Alaska        2010        1.843539              -0.418007            2.548387
# Arizona       2010       -1.328119              -0.842933           -0.732696
# Arkansas      2010       -1.697088              -1.865652           -1.209944
# California    2010       -0.062665              -0.095668            1.474578
# ...                            ...                    ...                 ...
# Virginia      2019        1.046644               1.360426            0.221801
# Washington    2019        2.410577               1.571630           -1.209944
# West Virginia 2019       -0.852549              -1.690006            0.022948
# Wisconsin     2019        0.578692               0.819605           -0.394645
# Wyoming       2019        1.457382               0.048041           -0.553728
#
# [500 rows x 9 columns]

# %%
scaler = StandardScaler()
scaler.set_output(transform = "pandas")
scaler.fit_transform(state_econ)
# Out:
#                         gini  min_wage  unemployment  GDP (in millions USD)  \
# State         Year
# Alabama       2010  0.531890 -0.268193      2.062574              -0.399253
# Alaska        2010 -2.025275  0.065214      1.062169              -0.672484
# Arizona       2010 -0.337546 -0.268193      2.029103              -0.237228
# Arkansas      2010 -0.184116 -0.935007      0.939443              -0.565390
# California    2010  0.480747  0.231918      2.992318               3.610467
# ...                      ...       ...           ...                    ...
# Virginia      2019  0.378460 -0.268193     -1.336570               0.451366
# Washington    2019 -0.199459  3.899397     -0.678312               0.576452
# West Virginia 2019  0.143201  0.732029     -0.365918              -0.614689
# Wisconsin     2019 -1.150724 -0.268193     -1.154341              -0.011344
# Wyoming       2019 -1.385983 -1.668503     -0.908888              -0.700421
#
#                     Population  Residents with Bachelor's Degree or Higher  \
# State         Year
# Alabama       2010   -0.224515                                   -0.397237
# Alaska        2010   -0.798499                                   -0.777665
# Arizona       2010    0.005067                                   -0.128308
# Arkansas      2010   -0.487263                                   -0.596752
# California    2010    4.366450                                    4.053519
# ...                        ...                                         ...
# Virginia      2019    0.304201                                    0.534247
# Washington    2019    0.174409                                    0.418926
# West Virginia 2019   -0.646497                                   -0.694071
# Wisconsin     2019   -0.078296                                    0.018936
# Wyoming       2019   -0.817563                                   -0.788510
#
#                     GDP per Capita  % with College Degree  Union Membership %
# State         Year
# Alabama       2010       -1.508554              -1.608426            0.003062
# Alaska        2010        1.843539              -0.418007            2.548387
# Arizona       2010       -1.328119              -0.842933           -0.732696
# Arkansas      2010       -1.697088              -1.865652           -1.209944
# California    2010       -0.062665              -0.095668            1.474578
# ...                            ...                    ...                 ...
# Virginia      2019        1.046644               1.360426            0.221801
# Washington    2019        2.410577               1.571630           -1.209944
# West Virginia 2019       -0.852549              -1.690006            0.022948
# Wisconsin     2019        0.578692               0.819605           -0.394645
# Wyoming       2019        1.457382               0.048041           -0.553728
#
# [500 rows x 9 columns]

# %%
model = sm.OLS(state_econ["gini"], sm.add_constant(state_econ[state_econ.columns[1:]]))

# %%
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   gini   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     25.53
# Date:                Sun, 26 Nov 2023   Prob (F-statistic):           5.50e-33
# Time:                        15:50:09   Log-Likelihood:                 1344.8
# No. Observations:                 500   AIC:                            -2672.
# Df Residuals:                     491   BIC:                            -2634.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# const                                          0.4780      0.009     50.860      0.000       0.459       0.496
# min_wage                                       0.0014      0.001      2.492      0.013       0.000       0.003
# unemployment                               -8.905e-05      0.000     -0.224      0.823      -0.001       0.001
# GDP (in millions USD)                       8.242e-09   1.32e-08      0.625      0.532   -1.77e-08    3.42e-08
# Population                                 -1.746e-09   1.21e-09     -1.446      0.149   -4.12e-09    6.26e-10
# Residents with Bachelor's Degree or Higher  2.052e-08   1.23e-08      1.665      0.097    -3.7e-09    4.47e-08
# GDP per Capita                                -0.1047      0.105     -0.999      0.318      -0.311       0.101
# % with College Degree                         -0.2287      0.069     -3.328      0.001      -0.364      -0.094
# Union Membership %                          -7.29e-05      0.000     -0.472      0.637      -0.000       0.000
# ==============================================================================
# Omnibus:                        0.494   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.781   Jarque-Bera (JB):                0.329
# Skew:                          -0.032   Prob(JB):                        0.848
# Kurtosis:                       3.108   Cond. No.                     1.44e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
